# %%
import pandas as pd
from os import listdir
import pickle
import matplotlib.pyplot as plt

def estimation_summary(res, target_recall=.9, target_cost=.2, filename=''):
    df = pd.DataFrame(res['supervised'])  
    ground_truth = res['true']
    ground_truth


    clf_df = df.loc[df.x >=df.thres].iloc[0]
    sup_pos = clf_df['pos']
    sup_est = clf_df['est']
    sup_cost = clf_df['x']

    recall_90_df = df.loc[df.est*.9 <= df.pos].iloc[0]
    stop_90_pos = recall_90_df['pos']
    stop_90_est = recall_90_df['est']
    stop_90_cost = recall_90_df['x']
    
    recall_95_df = df.loc[df.est*.95 <= df.pos].iloc[0]
    stop_95_pos = recall_95_df['pos']
    stop_95_est = recall_95_df['est']
    stop_95_cost = recall_95_df['x']


    five_df = df.loc[df.x >= (ground_truth[1] * .05)].iloc[0]
    five_pos = five_df['pos']
    five_est = five_df['est']
    five_cost = five_df['x']
    
    ten_df = df.loc[df.x >= (ground_truth[1] * .1)].iloc[0]
    ten_pos = ten_df['pos']
    ten_est = ten_df['est']
    ten_cost = ten_df['x']
    
    twenty_df = df.loc[df.x >= (ground_truth[1] * .2)].iloc[0]
    twenty_pos = twenty_df['pos']
    twenty_est = twenty_df['est']
    twenty_cost = twenty_df['x']
    
    thirty_df = df.loc[df.x >= (ground_truth[1] * .3)].iloc[0]
    thirty_pos = thirty_df['pos']
    thirty_est = thirty_df['est']
    thirty_cost = thirty_df['x']
    
    forty_df = df.loc[df.x >= (ground_truth[1] * .4)].iloc[0]
    forty_pos = forty_df['pos']
    forty_est = forty_df['est']
    forty_cost = forty_df['x']
    
    fifty_df = df.loc[df.x >= (ground_truth[1] * .5)].iloc[0]
    fifty_pos = fifty_df['pos']
    fifty_est = fifty_df['est']
    fifty_cost = fifty_df['x']
    
    
    print("FILENAME: " + filename)
    print("TRUE:", ground_truth)
    print("CLF:")
    print("True recall: %.4f, est recall: %.4f, precision: %.4f" %(sup_pos/ground_truth[0], sup_pos/sup_est, sup_pos/float(sup_cost)))

    print("Target Cost %.2f:" %.05)
    print("Est: %.2f, Accu: %.2f, Read: %.2f, Cost: %.2f, Found: %.2f, Recall: %.2f" %(five_est, five_est/ground_truth[0]*100, 
                                                                                      five_cost, five_cost/ground_truth[1]*100, 
                                                                                      five_pos, five_pos/ground_truth[0]*100))
    
    print("Target Cost %.2f:" %.1)
    print("Est: %.2f, Accu: %.2f, Read: %.2f, Cost: %.2f, Found: %.2f, Recall: %.2f" %(ten_est, ten_est/ground_truth[0]*100, 
                                                                                      ten_cost, ten_cost/ground_truth[1]*100, 
                                                                                      ten_pos, ten_pos/ground_truth[0]*100))
    
    
    print("Target Cost %.2f:" %.2)
    print("Est: %.2f, Accu: %.2f, Read: %.2f, Cost: %.2f, Found: %.2f, Recall: %.2f" %(twenty_est, twenty_est/ground_truth[0]*100, 
                                                                                      twenty_cost, twenty_cost/ground_truth[1]*100, 
                                                                                      twenty_pos, twenty_pos/ground_truth[0]*100))
    
    print("Target Cost %.2f:" %.3)
    print("Est: %.2f, Accu: %.2f, Read: %.2f, Cost: %.2f, Found: %.2f, Recall: %.2f" %(thirty_est, thirty_est/ground_truth[0]*100, 
                                                                                      thirty_cost, thirty_cost/ground_truth[1]*100, 
                                                                                      thirty_pos, thirty_pos/ground_truth[0]*100))
    
    print("Target Cost %.2f:" %.4)
    print("Est: %.2f, Accu: %.2f, Read: %.2f, Cost: %.2f, Found: %.2f, Recall: %.2f" %(forty_est, forty_est/ground_truth[0]*100, 
                                                                                      forty_cost, forty_cost/ground_truth[1]*100, 
                                                                                      forty_pos, forty_pos/ground_truth[0]*100))
    
    print("Target Cost %.2f:" %.5)
    print("Est: %.2f, Accu: %.2f, Read: %.2f, Cost: %.2f, Found: %.2f, Recall: %.2f" %(fifty_est, fifty_est/ground_truth[0]*100, 
                                                                                      fifty_cost, fifty_cost/ground_truth[1]*100, 
                                                                                      fifty_pos, fifty_pos/ground_truth[0]*100))
    
    
    print("Target Recall %.2f:" %.9)
    print("Est: %.2f, Accu: %.2f, Read: %.2f, Cost: %.2f, Found: %.2f, Recall: %.2f" %(stop_90_est, stop_90_est/ground_truth[0]*100, 
                                                                                      stop_90_cost, stop_90_cost/ground_truth[1]*100, 
                                                                                      stop_90_pos, stop_90_pos/ground_truth[0]*100))    
    
    print("Target Recall %.2f:" %.95)
    print("Est: %.2f, Accu: %.2f, Read: %.2f, Cost: %.2f, Found: %.2f, Recall: %.2f" %(stop_95_est, stop_95_est/ground_truth[0]*100, 
                                                                                      stop_95_cost, stop_95_cost/ground_truth[1]*100, 
                                                                                      stop_95_pos, stop_95_pos/ground_truth[0]*100))    
    
    
    
    print("For LATEX")
    print('', int(round(five_pos/ground_truth[0]*100,0)), ' &\n', int(round(ten_pos/ground_truth[0]*100,0)), ' &\n', 
          int(round(twenty_pos/ground_truth[0]*100,0)), ' &\n', int(round(thirty_pos/ground_truth[0]*100,0)), ' &\n',
          int(round(forty_pos/ground_truth[0]*100,0)), ' &\n', int(round(fifty_pos/ground_truth[0]*100,0)), '&\n', 
          int(round(stop_90_cost/ground_truth[1]*100,0)), '&', int(round(stop_90_pos/ground_truth[0]*100,0)), '&\n', 
          int(round(stop_95_cost/ground_truth[1]*100,0)), '&', int(round(stop_95_pos/ground_truth[0]*100,0)), '\\\\')
    
    results = []
    results_cost = []
    results.append(round(five_pos/ground_truth[0]*100,0))
    results.append(round(ten_pos/ground_truth[0]*100,0))
    results.append(round(twenty_pos/ground_truth[0]*100,0))
    results.append(round(thirty_pos/ground_truth[0]*100,0))
    results.append(round(forty_pos/ground_truth[0]*100,0))
    results.append(round(fifty_pos/ground_truth[0]*100,0))
    results.append(round(stop_90_pos/ground_truth[0]*100,0)) #recall
    results.append(round(stop_90_cost/ground_truth[1]*100,0))
    results.append(round(stop_95_pos/ground_truth[0]*100,0)) #recall
    results.append(round(stop_95_cost/ground_truth[1]*100,0))

    print('\n')
    return results_cost, results
    
files = listdir('../../dump_90_7')
df = pd.DataFrame()
for file in files:
    with open('../../dump_90_7/' + file, "rb") as handle:
        res = pickle.load(handle)
        filename = file.rsplit('.',1)[0]
        print(filename) 
        results_cost, results_target = estimation_summary(res, filename=filename)
        df[filename] = results_target
df = df.T
cols = ['5', '10', '20', '30', '40', '50', 'T90Recall', 'T90Cost', 'T95Recall', 'T95Cost']
df.columns = cols
#df = df.T


print(df.describe().loc['75%'] - df.describe().loc['25%'])
df
# Out:
# apache-ant-1.7.0
# FILENAME: apache-ant-1.7.0
# TRUE: [131, 4098]
# CLF:
# True recall: 0.6336, est recall: 0.6917, precision: 0.3320
# Target Cost 0.05:
# Est: 117.00, Accu: 89.31, Read: 210.00, Cost: 5.12, Found: 77.00, Recall: 58.78
# Target Cost 0.10:
# Est: 120.00, Accu: 91.60, Read: 410.00, Cost: 10.00, Found: 94.00, Recall: 71.76
# Target Cost 0.20:
# Est: 119.00, Accu: 90.84, Read: 820.00, Cost: 20.01, Found: 105.00, Recall: 80.15
# Target Cost 0.30:
# Est: 119.00, Accu: 90.84, Read: 1230.00, Cost: 30.01, Found: 111.00, Recall: 84.73
# Target Cost 0.40:
# Est: 118.00, Accu: 90.08, Read: 1640.00, Cost: 40.02, Found: 115.00, Recall: 87.79
# Target Cost 0.50:
# Est: 120.00, Accu: 91.60, Read: 2050.00, Cost: 50.02, Found: 117.00, Recall: 89.31
# Target Recall 0.90:
# Est: 117.00, Accu: 89.31, Read: 920.00, Cost: 22.45, Found: 107.00, Recall: 81.68
# Target Recall 0.95:
# Est: 118.00, Accu: 90.08, Read: 1440.00, Cost: 35.14, Found: 113.00, Recall: 86.26
# For LATEX
#  59  &
#  72  &
#  80  &
#  85  &
#  88  &
#  89 &
#  22 & 82 &
#  35 & 86 \\
#
#
# apache-jmeter-2.10
# FILENAME: apache-jmeter-2.10
# TRUE: [374, 8057]
# CLF:
# True recall: 0.7861, est recall: 0.8077, precision: 0.5345
# Target Cost 0.05:
# Est: 371.00, Accu: 99.20, Read: 410.00, Cost: 5.09, Found: 276.00, Recall: 73.80
# Target Cost 0.10:
# Est: 364.00, Accu: 97.33, Read: 810.00, Cost: 10.05, Found: 315.00, Recall: 84.22
# Target Cost 0.20:
# Est: 362.00, Accu: 96.79, Read: 1620.00, Cost: 20.11, Found: 332.00, Recall: 88.77
# Target Cost 0.30:
# Est: 367.00, Accu: 98.13, Read: 2420.00, Cost: 30.04, Found: 344.00, Recall: 91.98
# Target Cost 0.40:
# Est: 363.00, Accu: 97.06, Read: 3230.00, Cost: 40.09, Found: 350.00, Recall: 93.58
# Target Cost 0.50:
# Est: 363.00, Accu: 97.06, Read: 4030.00, Cost: 50.02, Found: 350.00, Recall: 93.58
# Target Recall 0.90:
# Est: 366.00, Accu: 97.86, Read: 1130.00, Cost: 14.03, Found: 330.00, Recall: 88.24
# Target Recall 0.95:
# Est: 364.00, Accu: 97.33, Read: 2770.00, Cost: 34.38, Found: 346.00, Recall: 92.51
# For LATEX
#  74  &
#  84  &
#  89  &
#  92  &
#  94  &
#  94 &
#  14 & 88 &
#  34 & 93 \\
#
#
# argouml
# FILENAME: argouml
# TRUE: [1413, 9452]
# CLF:
# True recall: 0.8705, est recall: 0.9311, precision: 0.7193
# Target Cost 0.05:
# Est: 880.00, Accu: 62.28, Read: 480.00, Cost: 5.08, Found: 378.00, Recall: 26.75
# Target Cost 0.10:
# Est: 1060.00, Accu: 75.02, Read: 950.00, Cost: 10.05, Found: 772.00, Recall: 54.64
# Target Cost 0.20:
# Est: 1359.00, Accu: 96.18, Read: 1900.00, Cost: 20.10, Found: 1281.00, Recall: 90.66
# Target Cost 0.30:
# Est: 1431.00, Accu: 101.27, Read: 2840.00, Cost: 30.05, Found: 1387.00, Recall: 98.16
# Target Cost 0.40:
# Est: 1425.00, Accu: 100.85, Read: 3790.00, Cost: 40.10, Found: 1399.00, Recall: 99.01
# Target Cost 0.50:
# Est: 1424.00, Accu: 100.78, Read: 4730.00, Cost: 50.04, Found: 1403.00, Recall: 99.29
# Target Recall 0.90:
# Est: 1249.00, Accu: 88.39, Read: 1450.00, Cost: 15.34, Found: 1127.00, Recall: 79.76
# Target Recall 0.95:
# Est: 1358.00, Accu: 96.11, Read: 1930.00, Cost: 20.42, Found: 1296.00, Recall: 91.72
# For LATEX
#  27  &
#  55  &
#  91  &
#  98  &
#  99  &
#  99 &
#  15 & 80 &
#  20 & 92 \\
#
#
# columba-1.4-src
# FILENAME: columba-1.4-src
# TRUE: [204, 6468]
# CLF:
# True recall: 0.9363, est recall: 0.7828, precision: 0.5457
# Target Cost 0.05:
# Est: 245.00, Accu: 120.10, Read: 330.00, Cost: 5.10, Found: 190.00, Recall: 93.14
# Target Cost 0.10:
# Est: 229.00, Accu: 112.25, Read: 650.00, Cost: 10.05, Found: 196.00, Recall: 96.08
# Target Cost 0.20:
# Est: 219.00, Accu: 107.35, Read: 1300.00, Cost: 20.10, Found: 198.00, Recall: 97.06
# Target Cost 0.30:
# Est: 215.00, Accu: 105.39, Read: 1950.00, Cost: 30.15, Found: 201.00, Recall: 98.53
# Target Cost 0.40:
# Est: 211.00, Accu: 103.43, Read: 2590.00, Cost: 40.04, Found: 203.00, Recall: 99.51
# Target Cost 0.50:
# Est: 210.00, Accu: 102.94, Read: 3240.00, Cost: 50.09, Found: 204.00, Recall: 100.00
# Target Recall 0.90:
# Est: 220.00, Accu: 107.84, Read: 1170.00, Cost: 18.09, Found: 198.00, Recall: 97.06
# Target Recall 0.95:
# Est: 212.00, Accu: 103.92, Read: 2310.00, Cost: 35.71, Found: 202.00, Recall: 99.02
# For LATEX
#  93  &
#  96  &
#  97  &
#  99  &
#  100  &
#  100 &
#  18 & 97 &
#  36 & 99 \\
#
#
# emf-2.4.1
# FILENAME: emf-2.4.1
# TRUE: [104, 4390]
# CLF:
# True recall: 0.4808, est recall: 0.5435, precision: 0.1923
# Target Cost 0.05:
# Est: 92.00, Accu: 88.46, Read: 220.00, Cost: 5.01, Found: 47.00, Recall: 45.19
# Target Cost 0.10:
# Est: 85.00, Accu: 81.73, Read: 440.00, Cost: 10.02, Found: 57.00, Recall: 54.81
# Target Cost 0.20:
# Est: 87.00, Accu: 83.65, Read: 880.00, Cost: 20.05, Found: 70.00, Recall: 67.31
# Target Cost 0.30:
# Est: 85.00, Accu: 81.73, Read: 1320.00, Cost: 30.07, Found: 76.00, Recall: 73.08
# Target Cost 0.40:
# Est: 92.00, Accu: 88.46, Read: 1760.00, Cost: 40.09, Found: 86.00, Recall: 82.69
# Target Cost 0.50:
# Est: 97.00, Accu: 93.27, Read: 2200.00, Cost: 50.11, Found: 92.00, Recall: 88.46
# Target Recall 0.90:
# Est: 86.00, Accu: 82.69, Read: 1390.00, Cost: 31.66, Found: 78.00, Recall: 75.00
# Target Recall 0.95:
# Est: 93.00, Accu: 89.42, Read: 2030.00, Cost: 46.24, Found: 89.00, Recall: 85.58
# For LATEX
#  45  &
#  55  &
#  67  &
#  73  &
#  83  &
#  88 &
#  32 & 75 &
#  46 & 86 \\
#
#
# hibernate-distribution-3.3.2.GA
# FILENAME: hibernate-distribution-3.3.2.GA
# TRUE: [472, 2968]
# CLF:
# True recall: 0.8284, est recall: 0.9376, precision: 0.7241
# Target Cost 0.05:
# Est: 296.00, Accu: 62.71, Read: 150.00, Cost: 5.05, Found: 139.00, Recall: 29.45
# Target Cost 0.10:
# Est: 365.00, Accu: 77.33, Read: 300.00, Cost: 10.11, Found: 279.00, Recall: 59.11
# Target Cost 0.20:
# Est: 420.00, Accu: 88.98, Read: 600.00, Cost: 20.22, Found: 399.00, Recall: 84.53
# Target Cost 0.30:
# Est: 433.00, Accu: 91.74, Read: 900.00, Cost: 30.32, Found: 422.00, Recall: 89.41
# Target Cost 0.40:
# Est: 441.00, Accu: 93.43, Read: 1190.00, Cost: 40.09, Found: 436.00, Recall: 92.37
# Target Cost 0.50:
# Est: 448.00, Accu: 94.92, Read: 1490.00, Cost: 50.20, Found: 444.00, Recall: 94.07
# Target Recall 0.90:
# Est: 403.00, Accu: 85.38, Read: 430.00, Cost: 14.49, Found: 363.00, Recall: 76.91
# Target Recall 0.95:
# Est: 420.00, Accu: 88.98, Read: 600.00, Cost: 20.22, Found: 399.00, Recall: 84.53
# For LATEX
#  29  &
#  59  &
#  85  &
#  89  &
#  92  &
#  94 &
#  14 & 77 &
#  20 & 85 \\
#
#
# jEdit-4.2
# FILENAME: jEdit-4.2
# TRUE: [256, 10322]
# CLF:
# True recall: 0.4961, est recall: 0.6135, precision: 0.5292
# Target Cost 0.05:
# Est: 222.00, Accu: 86.72, Read: 520.00, Cost: 5.04, Found: 157.00, Recall: 61.33
# Target Cost 0.10:
# Est: 233.00, Accu: 91.02, Read: 1040.00, Cost: 10.08, Found: 175.00, Recall: 68.36
# Target Cost 0.20:
# Est: 213.00, Accu: 83.20, Read: 2070.00, Cost: 20.05, Found: 175.00, Recall: 68.36
# Target Cost 0.30:
# Est: 219.00, Accu: 85.55, Read: 3100.00, Cost: 30.03, Found: 196.00, Recall: 76.56
# Target Cost 0.40:
# Est: 226.00, Accu: 88.28, Read: 4130.00, Cost: 40.01, Found: 211.00, Recall: 82.42
# Target Cost 0.50:
# Est: 239.00, Accu: 93.36, Read: 5170.00, Cost: 50.09, Found: 227.00, Recall: 88.67
# Target Recall 0.90:
# Est: 217.00, Accu: 84.77, Read: 3230.00, Cost: 31.29, Found: 196.00, Recall: 76.56
# Target Recall 0.95:
# Est: 235.00, Accu: 91.80, Read: 4760.00, Cost: 46.12, Found: 224.00, Recall: 87.50
# For LATEX
#  61  &
#  68  &
#  68  &
#  77  &
#  82  &
#  89 &
#  31 & 77 &
#  46 & 88 \\
#
#
# jfreechart-1.0.19
# FILENAME: jfreechart-1.0.19
# TRUE: [209, 4408]
# CLF:
# True recall: 0.5694, est recall: 0.7987, precision: 0.3216
# Target Cost 0.05:
# Est: 162.00, Accu: 77.51, Read: 230.00, Cost: 5.22, Found: 115.00, Recall: 55.02
# Target Cost 0.10:
# Est: 144.00, Accu: 68.90, Read: 450.00, Cost: 10.21, Found: 120.00, Recall: 57.42
# Target Cost 0.20:
# Est: 202.00, Accu: 96.65, Read: 890.00, Cost: 20.19, Found: 190.00, Recall: 90.91
# Target Cost 0.30:
# Est: 202.00, Accu: 96.65, Read: 1330.00, Cost: 30.17, Found: 195.00, Recall: 93.30
# Target Cost 0.40:
# Est: 203.00, Accu: 97.13, Read: 1770.00, Cost: 40.15, Found: 198.00, Recall: 94.74
# Target Cost 0.50:
# Est: 202.00, Accu: 96.65, Read: 2210.00, Cost: 50.14, Found: 198.00, Recall: 94.74
# Target Recall 0.90:
# Est: 144.00, Accu: 68.90, Read: 740.00, Cost: 16.79, Found: 131.00, Recall: 62.68
# Target Recall 0.95:
# Est: 148.00, Accu: 70.81, Read: 830.00, Cost: 18.83, Found: 142.00, Recall: 67.94
# For LATEX
#  55  &
#  57  &
#  91  &
#  93  &
#  95  &
#  95 &
#  17 & 63 &
#  19 & 68 \\
#
#
# jruby-1.4.0
# FILENAME: jruby-1.4.0
# TRUE: [622, 4897]
# CLF:
# True recall: 0.9212, est recall: 0.9487, precision: 0.6821
# Target Cost 0.05:
# Est: 446.00, Accu: 71.70, Read: 250.00, Cost: 5.11, Found: 229.00, Recall: 36.82
# Target Cost 0.10:
# Est: 540.00, Accu: 86.82, Read: 490.00, Cost: 10.01, Found: 439.00, Recall: 70.58
# Target Cost 0.20:
# Est: 612.00, Accu: 98.39, Read: 980.00, Cost: 20.01, Found: 585.00, Recall: 94.05
# Target Cost 0.30:
# Est: 617.00, Accu: 99.20, Read: 1470.00, Cost: 30.02, Found: 605.00, Recall: 97.27
# Target Cost 0.40:
# Est: 617.00, Accu: 99.20, Read: 1960.00, Cost: 40.02, Found: 610.00, Recall: 98.07
# Target Cost 0.50:
# Est: 616.00, Accu: 99.04, Read: 2450.00, Cost: 50.03, Found: 612.00, Recall: 98.39
# Target Recall 0.90:
# Est: 582.00, Accu: 93.57, Read: 630.00, Cost: 12.87, Found: 529.00, Recall: 85.05
# Target Recall 0.95:
# Est: 605.00, Accu: 97.27, Read: 880.00, Cost: 17.97, Found: 575.00, Recall: 92.44
# For LATEX
#  37  &
#  71  &
#  94  &
#  97  &
#  98  &
#  98 &
#  13 & 85 &
#  18 & 92 \\
#
#
# sql12
# FILENAME: sql12
# TRUE: [286, 7215]
# CLF:
# True recall: 0.6434, est recall: 0.7244, precision: 0.4718
# Target Cost 0.05:
# Est: 248.00, Accu: 86.71, Read: 370.00, Cost: 5.13, Found: 182.00, Recall: 63.64
# Target Cost 0.10:
# Est: 253.00, Accu: 88.46, Read: 730.00, Cost: 10.12, Found: 214.00, Recall: 74.83
# Target Cost 0.20:
# Est: 277.00, Accu: 96.85, Read: 1450.00, Cost: 20.10, Found: 259.00, Recall: 90.56
# Target Cost 0.30:
# Est: 284.00, Accu: 99.30, Read: 2170.00, Cost: 30.08, Found: 269.00, Recall: 94.06
# Target Cost 0.40:
# Est: 283.00, Accu: 98.95, Read: 2890.00, Cost: 40.06, Found: 274.00, Recall: 95.80
# Target Cost 0.50:
# Est: 283.00, Accu: 98.95, Read: 3610.00, Cost: 50.03, Found: 277.00, Recall: 96.85
# Target Recall 0.90:
# Est: 265.00, Accu: 92.66, Read: 1140.00, Cost: 15.80, Found: 240.00, Recall: 83.92
# Target Recall 0.95:
# Est: 282.00, Accu: 98.60, Read: 1950.00, Cost: 27.03, Found: 268.00, Recall: 93.71
# For LATEX
#  64  &
#  75  &
#  91  &
#  94  &
#  96  &
#  97 &
#  16 & 84 &
#  27 & 94 \\
#
#
# 5            24.25
# 10           16.75
# 20            9.75
# 30           10.25
# 40            8.50
# 50            7.50
# T90Recall     7.75
# T90Cost       6.75
# T95Recall     6.75
# T95Cost      15.75
# dtype: float64
#                                     5    10    20    30     40     50  \
# apache-ant-1.7.0                 59.0  72.0  80.0  85.0   88.0   89.0
# apache-jmeter-2.10               74.0  84.0  89.0  92.0   94.0   94.0
# argouml                          27.0  55.0  91.0  98.0   99.0   99.0
# columba-1.4-src                  93.0  96.0  97.0  99.0  100.0  100.0
# emf-2.4.1                        45.0  55.0  67.0  73.0   83.0   88.0
# hibernate-distribution-3.3.2.GA  29.0  59.0  85.0  89.0   92.0   94.0
# jEdit-4.2                        61.0  68.0  68.0  77.0   82.0   89.0
# jfreechart-1.0.19                55.0  57.0  91.0  93.0   95.0   95.0
# jruby-1.4.0                      37.0  71.0  94.0  97.0   98.0   98.0
# sql12                            64.0  75.0  91.0  94.0   96.0   97.0
#
#                                  T90Recall  T90Cost  T95Recall  T95Cost
# apache-ant-1.7.0                      82.0     22.0       86.0     35.0
# apache-jmeter-2.10                    88.0     14.0       93.0     34.0
# argouml                               80.0     15.0       92.0     20.0
# columba-1.4-src                       97.0     18.0       99.0     36.0
# emf-2.4.1                             75.0     32.0       86.0     46.0
# hibernate-distribution-3.3.2.GA       77.0     14.0       85.0     20.0
# jEdit-4.2                             77.0     31.0       88.0     46.0
# jfreechart-1.0.19                     63.0     17.0       68.0     19.0
# jruby-1.4.0                           85.0     13.0       92.0     18.0
# sql12                                 84.0     16.0       94.0     27.0
